# %%
#Q1
print('='*5, 'Q1 Text from users')
print("Teach me words: ")


starting_program = ("Handong Global University is a four-year, Christian university located in Pohang, \
South Korea. With students and faculty from more than 50 countries worldwide, Handong \
Global University provides an optimal global community to experience cultural diversity \
and develop global competence. Handong Global University fosters world-changing leaders \
by pursuing academic excellence and holistic education based on the Christian faith. As \
a Christian institution of higher learning, Handong Global University will be an example \
of a 'global' university that serves our neighbors and the world with love, wisdom, and \
creativity. Handong's educational objective is 'fostering new leaders with the Christian \
spirit, academic excellence, global citizenship mindset, and biblical values-particularly \
integrity and the spirit of service-necessary to change the world.' This goal is \
represented in the Chinese character 工 ('mastery'), which highlights global and \
creative capacity, professionalism, and upright character and values.")

print(starting_program)
print('\n, \n')

#Q2A
Q2A_list=starting_program.split()
print('='*5, 'Q2-A All words:', len(Q2A_list),'words')
print(Q2A_list)

#Q2B
print('\n, \n')
lowercase_list=[word.lower() for word in Q2A_list]
Q2A_list=list(dict.fromkeys(lowercase_list))
print('='*5, 'Q2-B Duplicated removed(case-insensitive)', len(Q2A_list), 'words')
print(Q2A_list)

#Q2C
print('\n, \n')
length_list=[word for word in Q2A_list if len(word)>=3]
print('='*5, 'Q2-C Words whose length is greater than 2', len(length_list), 'words')
print(Q2A_list)

#Q2D
from string import punctuation
print('\n, \n')

punct_removed_list = length_list.copy()
for word in length_list:
    for char in word:
        if char in punctuation:
            try:
                punct_removed_list.remove(word)
                continue
            except:
                continue

print('='*5, 'Q2-D Words with punctuation marks removed', len(punct_removed_list), 'words')
print(punct_removed_list)

#Q2E
print('\n, \n')
from string import punctuation
ascending_list=sorted(punct_removed_list)
print('='*5, 'Q2E Words in ascending order')
print(ascending_list)


"""
user_word: user's input
ll_of_cs: last letter of computer's word
"""
def q_5(user_word, ll_of_cw):
    
    #check if user's word length is less than three or if the 
    #initial word matches to the computer's word's last letter
    
    #if condition not met:
    if ll_of_cw != user_word[0] or len(user_word) < 3:
        print("computer-has-won because condition not met")
        #return False if computer wins
        return False
    else:
        #return True if computer does not win
        return True
"""
list_of_words: list of words the computer draws its word out from
ll_of_uw: last letter of user's word
"""
def q_7(list_of_words, ll_of_uw):
    for word in list_of_words:
        if ll_of_uw == word[0]:
            new_word = word
            #return new_word if there is a matching word is 'list_of_word'
            return new_word
    #return False if the user wins
    return False

record = {}

#ordered_word_ls: copy of ascending_list
ordered_word_ls = ascending_list.copy()
#computers_word: word which the computer chooses
computers_word = random.choice(ordered_word_ls)
ascending_list.remove(computers_word)

#import datetime library
from datetime import datetime

#print('='*5, "Q3 Let's play the game with this word:", computers_word)
#user_word = input('Enter a at-least-3 characters word starting with the last letter of:{}'.format(computers_word))

count = 0
#iterate while true
while True:
    
    #print computers word
    print('='*5, "Q3 Let's play the game with this word:", computers_word)
    #get word from user
    user_word = input('Enter a at-least-3 characters word starting with the last letter of:{}'.format(computers_word))
    
    #if user's word does not meet the requirements 
    if q_5(user_word, computers_word[-1]) == False:
        now = datetime.now()
        dt_string = now.strftime("%Y/%m/%d %H:%M:%S") 
        record[dt_string] = 'computer'
        
        play_again = input("Do you want to play again?[y/n]:")
        #ask user if he/she wants to play again
        if play_again == 'y':
            continue
        else:
            print(record)
            break

    else:
        
        #select new computer's word
        computers_word = q_7(ascending_list, user_word[-1])
        
        #if word no longer in word list
        if computers_word == False:
            print("user-has-won because word not in word list")

            now = datetime.now()
            dt_string = now.strftime("%Y/%m/%d %H:%M:%S") 
            record[dt_string] = 'computer'

            play_again = input("Do you want to play again?[y/n]:")
            if play_again == 'y':
                continue
            elif play_again == 'n':
                print(record)
                break
        
        try:
            ascending_list.remove(computers_word)
        except:
            continue
# Out:
# ===== Q1 Text from users
# Teach me words:
# ...

# %%
def q_5(user_word, ll_of_cw):
    if ll_of_cw != user_word[0] or len(user_word) < 3:
        print("computer-has-won because condition not met")
        #return False if computer wins
        return False
    else:
        #return if computer does not win
        return True
    
def q_7(list_of_words, ll_of_uw):
    for word in list_of_words:
        if ll_of_uw == word[0]:
            new_word = word
            #return new_word if there is a matching word is 'list_of_word'
            return new_word
    print("user-has-won because word not in word list")
    #return False if the user wins
    return False

"""
user_word: user's input
ll_of_cs: last letter of computer's word
"""
def q_5(user_word, ll_of_cw):
    
    #check if user's word length is less than three or if the 
    #initial word matches to the computer's word's last letter
    
    #if condition not met:
    if ll_of_cw != user_word[0] or len(user_word) < 3:
        print("computer-has-won because condition not met")
        #return False if computer wins
        return False
    else:
        #return True if computer does not win
        return True
"""
list_of_words: list of words the computer draws its word out from
ll_of_uw: last letter of user's word
"""
def q_7(list_of_words, ll_of_uw):
    for word in list_of_words:
        if ll_of_uw == word[0]:
            new_word = word
            #return new_word if there is a matching word is 'list_of_word'
            return new_word
    print("user-has-won because word not in word list")
    #return False if the user wins
    return False

record = {}

#ordered_word_ls: copy of ascending_list
ordered_word_ls = ascending_list.copy()
#computers_word: word which the computer chooses
computers_word = random.choice(ordered_word_ls)
ordered_word_ls.remove(computers_word)

#import datetime library
from datetime import datetime

#print('='*5, "Q3 Let's play the game with this word:", computers_word)
#user_word = input('Enter a at-least-3 characters word starting with the last letter of:{}'.format(computers_word))

count = 0
#iterate while true
while True:
    
    #print computers word
    print('='*5, "Q3 Let's play the game with this word:", computers_word)
    #get word from user
    user_word = input('Enter a at-least-3 characters word starting with the last letter of:{}'.format(computers_word))
    
    #if user's word does not meet the requirements 
    if q_5(user_word, computers_word[-1]) == False:
        now = datetime.now()
        dt_string = now.strftime("%Y/%m/%d %H:%M:%S") 
        record[dt_string] = 'computer'
        
        play_again = input("Do you want to play again?[y/n]:")
        #ask user if he/she wants to play again
        if play_again == 'y':
            continue
        else:
            print(record)
            break
    #if word no longer in word list
    if computers_word == False:
        print("user-has-won because word not in word list")
        
        now = datetime.now()
        dt_string = now.strftime("%Y/%m/%d %H:%M:%S") 
        record[dt_string] = 'computer'
        
        play_again = input("Do you want to play again?[y/n]:")
        if play_again == 'y':
            continue
        elif play_again == 'n':
            print(record)
            break
    else:
        #select new computer's word
        computers_word = q_7(ascending_list, user_word[-1])
# Out:
# ===== Q3 Let's play the game with this word: will
# Enter a at-least-3 characters word starting with the last letter of:will lego
# ===== Q3 Let's play the game with this word: objective
# Enter a at-least-3 characters word starting with the last letter of:objective eva
# ===== Q3 Let's play the game with this word: academic
# Enter a at-least-3 characters word starting with the last letter of:academic cadillac
# ===== Q3 Let's play the game with this word: change
# Enter a at-least-3 characters word starting with the last letter of:change esd
# ===== Q3 Let's play the game with this word: develop
# Enter a at-least-3 characters word starting with the last letter of:develop edi
# computer-has-won because condition not met
# Do you want to play again?[y/n]: y
# ===== Q3 Let's play the game with this word: develop
# Enter a at-least-3 characters word starting with the last letter of:develop pipe
# ===== Q3 Let's play the game with this word: education
# ...

# %% [raw]
# """
# user_word: user's input
# ll_of_cs: last letter of computer's word
# """
# def q_5(user_word, ll_of_cw):
#
#     #check if user's word length is less than three or if the
#     #initial word matches to the computer's word's last letter
#
#     #if condition not met:
#     if ll_of_cw != user_word[0] or len(user_word) < 3:
#         print("computer-has-won because condition not met")
#         #return False if computer wins
#         return False
#     else:
#         #return True if computer does not win
#         return True
# """
# list_of_words: list of words the computer draws its word out from
# ll_of_uw: last letter of user's word
# """
# def q_7(list_of_words, ll_of_uw):
#     for word in list_of_words:
#         if ll_of_uw == word[0]:
#             new_word = word
#             #return new_word if there is a matching word is 'list_of_word'
#             return new_word
#     print("user-has-won because word not in word list")
#     #return False if the user wins
#     return False
#
# record = {}
#
# #ordered_word_ls: copy of ascending_list
# ordered_word_ls = ascending_list.copy()
# #computers_word: word which the computer chooses
# computers_word = random.choice(ordered_word_ls)
# ordered_word_ls.remove(computers_word)
#
# #import datetime library
# from datetime import datetime
#
# #print('='*5, "Q3 Let's play the game with this word:", computers_word)
# #user_word = input('Enter a at-least-3 characters word starting with the last letter of:{}'.format(computers_word))
#
# count = 0
# #iterate while true
# while True:
#
#     #print computers word
#     print('='*5, "Q3 Let's play the game with this word:", computers_word)
#     #get word from user
#     user_word = input('Enter a at-least-3 characters word starting with the last letter of:{}'.format(computers_word))
#
#     #if user's word does not meet the requirements
#     if q_5(user_word, computers_word[-1]) == False:
#         now = datetime.now()
#         dt_string = now.strftime("%Y/%m/%d %H:%M:%S")
#         record[dt_string] = 'computer'
#
#         play_again = input("Do you want to play again?[y/n]:")
#         #ask user if he/she wants to play again
#         if play_again == 'y':
#             continue
#         else:
#             print(record)
#             break
#     #if word no longer in word list
#     if computers_word == False:
#         print("user-has-won because word not in word list")
#
#         now = datetime.now()
#         dt_string = now.strftime("%Y/%m/%d %H:%M:%S")
#         record[dt_string] = 'computer'
#
#         play_again = input("Do you want to play again?[y/n]:")
#         if play_again == 'y':
#             continue
#         elif play_again == 'n':
#             print(record)
#             break
#     else:
#         #select new computer's word
#         computers_word = q_7(ascending_list, user_word[-1])

# %%
import datetime
import random

def q5(user_word, com_word):
    if com_word != user_word[0] or len(user_word) < 3:
        print("computer has won")
        return False 
    else:
        return True

def q7(list_of_words, last_letter):
    for word in list_of_words:
        if last_letter == word[0]:
            new_word = word

            return new_word
        
    return False
# Q1
print("Teach me words:")

text = "Handong Global University is a four-year, Christian university located in Pohang, \
South Korea. With students and faculty from more than 50 countries worldwide, Handong \
Global University provides an optimal global community to experience cultural diversity \
and develop global competence. Handong Global University fosters world-changing leaders \
by pursuing academic excellence and holistic education based on the Christian faith. As \
a Christian institution of higher learning, Handong Global University will be an example \
of a 'global' university that serves our neighbors and the world with love, wisdom, and \
creativity. Handong's educational objective is 'fostering new leaders with the Christian \
spirit, academic excellence, global citizenship mindset, and biblical values-particularly \
integrity and the spirit of service-necessary to change the world.' This goal is \
represented in the Chinese character 工 ('mastery'), which highlights global and \
creative capacity, professionalism, and upright character and values."

print(text)
print() # seperator    

#Q2-A
white_space = text.split( )
print(white_space)
print("All words:", len(white_space))
print() # seperator    

#Q2-B
duplications = list(set([word.lower() for word in white_space]))
print(duplications)
print("Duplicated removed (case sensitive):", len(duplications))
print() # seperator    

#Q2-C
less_than = [word for word in duplications if len(word) >= 3]
print(less_than)
print("Words whose length is greater than 2", len(less_than))
print() # seperator    

#Q2-D
from string import punctuation
punc_removed_ls = less_than.copy()
for word in punc_removed_ls:
    for char in word:
        if char in punctuation:
            try:
                punc_removed_ls.remove(word)
                continue
            except:
                continue

#print(less_than)
print(punc_removed_ls)
print("Words with punctuation marks removed", len(less_than))
print("Words with punctuation marks removed", len(punc_removed_ls))
print() # seperator

#Q2-E
print("Words in ascending order")
sort = sorted(less_than)
print(sort)
print() # seperator

#Q3
import random
import datetime
#random_choice = random.choice(sort)
#print("Lets play a game with this word:", random_choice)
print() # seperator

win_lose = {}
 
#Q4
while True: #restart or no
    random_choice = random.choice(sort)
    print("Lets play a game with this word:", random_choice)
    while True: #game
        users_input = input("Enter at least a 3-character word starting with the last letter of: {}".format(random_choice))
        if not q5(users_input, random_choice[-1]):
            now = datetime.now()
            dt_string = now.strftime("%Y/%m/%d %H:%M:%S") 
            win_lose[dt_string] = 'computer'
            break
            

        if q7(sort, users_input[-1]) == False:
            print("user won")
            now = datetime.now()
            dt_string = now.strftime("%Y/%m/%d %H:%M:%S") 
            win_lose[dt_string] = 'user'
            break
        else:
            random_choice = q7(sort, users_input[-1])
            sort.remove(random_choice)

    play_again = input("Do you want to play again:")
    if play_again == 'yes':
        continue
    elif play_again == 'no':
        print(win_lose)
        break
# Out:
# Teach me words:
# ...
